# %% [markdown]
# <br><br>
# ## Now, a 667-long json file.
# ### or a list of 667 case dictionaries.
# My next steps should be to build a dataframe with the name of each case, see whether it's granted/denied (regex), see which country the plaintiff is from (regex), and the list of core terms I already have!
# <br><br>

# %%
import json
import re
import pandas as pd
with open('asylum_data_complete.json',"r") as f:
    all_asylum_cases = json.load(f)

# %% [markdown]
# #### First, finding the decisions and countries with regex

# %%
# This searches for either grant, or granted. 
# (although all the cases I've seen use granted, 
# I don't want to miss grant in case anyone uses it)
granted = r"\bGRANT\w{0,2}"

# This searches for either deny or denied.
denied = r"\bDENY?(IED)?"

# %%
# the pattern for country of citizenship is citizen(s) of [country]. 
# (in second item in opinion)
# Sometimes the country can be multiple words.
# But seems like the phrase describing 
# where someone's from is always separated by a comma
country = r"citizens?\s[\w\W]*of\s[\w\W]*[A-Z][^0-9]+,"

# %%
asylum_cases_organized = []

# %%
for asylum_case in all_asylum_cases:
    case = {}
    case["name"] = asylum_case["name"]
    conclusion = asylum_case["opinion"]
    if (re.search(granted, conclusion)):
        case["decision"] = "granted"
    elif (re.search(denied, conclusion)):
        case["decision"] = "denied"
    else:
        case["decision"] = None
        
    citizen = asylum_case["opinion"]
    case["country"] = re.search(country, citizen)
    case["terms"]  = asylum_case["terms"]
    case["op_length"] = len(asylum_case["opinion"])
    asylum_cases_organized.append(case)

# %%
asylum_cases_organized
# Out:
# [{'name': 'Zepeda-Lopez v. Garland, 38 F.4th 315',
#   'decision': 'granted',
#   'country': <re.Match object; span=(1027, 27063), match='citizens of both Honduras and Nicaragua. They app>,
#   'terms': ['refugee',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' nationality',
#    ' dual',
#    ' persecution',
#    ' citizenship',
#    ' singular',
#    ' removal',
#    ' legislative history',
#    ' resettlement',
#    ' well-founded',
#    ' withholding',
#    ' unwilling',
#    ' eligible',
#    ' deference',
#    ' qualify',
#    ' refugee status',
#    ' statutory text',
#    ' Immigration',
#    ' proceedings',
#    ' policies',
#    ' gang'],
#   'op_length': 27169},
#  {'name': 'Quituizaca v. Garland, 52 F.4th 103',
#   'decision': 'denied',
#   'country': <re.Match object; span=(1345, 40382), match='citizen of Ecuador, entered the United States in >,
#   'terms': ['withholding',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' removal',
#    ' motive',
#    ' persecution',
#    ' gang',
#    ' alien',
#    ' ethnicity',
#    ' but-for',
#    ' ambiguity',
#    ' causation',
#    ' withholding-of-removal',
#    ' eligibility',
#    ' Immigration',
#    ' concurrence',
#    ' credibility',
#    ' unambiguous',
#    ' deference',
#    ' burden of proof',
#    ' social group',
#    ' indigenous',
#    ' persuasive',
#    ' attacks',
#    ' waived',
#    ' petition for review',
#    ' plain meaning',
#    ' plain text',
#    ' nationality',
#    ' persecutor',
#    ' suggests'],
#   'op_length': 40390},
#  {'name': 'Liang v. Garland, 10 F.4th 106',
#   'decision': 'denied',
#   'country': <re.Match object; span=(819, 28175), match='citizen of the People\'s Republic of China, illeg>,
#   'terms': ['persecution',
#    ' blacklist',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' removal',
#    ' omission',
#    ' credibility',
#    ' credibility determinations',
#    ' withholding',
#    ' quotation',
#    ' marks',
#    ' cross-examination',
#    ' inconsistencies',
#    ' church',
#    ' totality of the circumstances',
#    ' well-founded',
#    ' corroborate',
#    ' disclose',
#    ' eligible'],
#   'op_length': 28201},
#  {'name': 'Doleck Nepali v. Barr, 828 Fed. Appx. 14',
#   'decision': 'denied',
#   'country': <re.Match object; span=(238, 9751), match='citizen of Nepal, seeks review of a November 28, >,
#   'terms': ['persecution',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' terrorist',
#    ' removal',
#    ' credibility determinations',
#    ' withholding',
#    ' credible'],
#   'op_length': 9853},
#  {'name': 'Fangfang Xu v. Cissna, 434 F. Supp. 3d 43',
#   'decision': 'granted',
#   'country': <re.Match object; span=(63, 43720), match='citizen of the People\'s Republic of China, appli>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' adjudicate',
#    ' delays',
#    ' motion to dismiss',
#    ' mandamus',
#    ' USCIS',
#    ' lack subject matter jurisdiction',
#    ' unreasonable delay',
#    " plaintiff's claim",
#    ' allegations',
#    ' fail to state a claim',
#    ' pleadings',
#    ' quotation',
#    ' due process',
#    ' time frame',
#    ' reasons',
#    ' courts',
#    ' alien',
#    ' marks',
#    ' subject matter jurisdiction',
#    ' immigration',
#    ' factors',
#    ' rights',
#    ' private right of action',
#    ' judicial review',
#    ' rule of reason',
#    ' timetable',
#    ' due process claim',
#    " plaintiff's right",
#    ' reasonable time'],
#   'op_length': 43803},
#  {'name': 'Kal Zhao v. Garland, 2022 U.S. App. LEXIS 6987',
#   'decision': 'denied',
#   'country': <re.Match object; span=(229, 7927), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['credible',
#    ' inconsistencies',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' demeanor',
#    ' attendance',
#    ' church',
#    ' removal',
#    ' credibility determinations',
#    ' corroborate',
#    ' withholding'],
#   'op_length': 8029},
#  {'name': 'Xin Lin v. Barr, 819 Fed. Appx. 38',
#   'decision': 'denied',
#   'country': <re.Match object; span=(220, 5851), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' persecution',
#    ' fraudulent',
#    ' factors',
#    ' reasons',
#    ' removal',
#    ' exercise of discretion',
#    ' abuse of discretion',
#    ' petition for review',
#    ' minor child',
#    ' discretionary',
#    ' withholding',
#    ' spouse',
#    ' totality of the circumstances',
#    ' reasonable alternative',
#    ' immigration law',
#    ' family unity',
#    ' family ties',
#    ' circumstances',
#    ' reunification',
#    ' speculative',
#    ' reconsider',
#    ' regulation',
#    ' violations',
#    ' envelope',
#    ' outweigh'],
#   'op_length': 5953},
#  {'name': 'Hernandez-Chacon v. Barr, 948 F.3d 94',
#   'decision': 'granted',
#   'country': <re.Match object; span=(100, 27273), match='citizen of El Salvador, seeks review of a decisio>,
#   'terms': ['political opinion',
#    ' persecution',
#    ' social group',
#    ' resisted',
#    ' gang',
#    ' gang member',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' daughter',
#    ' imputed',
#    ' rape',
#    ' attacked',
#    ' violence',
#    ' sexual advances',
#    ' corruption',
#    ' membership',
#    ' brutal',
#    ' punish',
#    ' kill'],
#   'op_length': 27438},
#  {'name': 'Zelaya-Moreno v. Wilkinson, 989 F.3d 190',
#   'decision': 'denied',
#   'country': <re.Match object; span=(301, 63457), match='citizen of El Salvador, testified before an Immig>,
#   'terms': ['gang',
#    ' political opinion',
#    ' torture',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' corruption',
#    ' persecution',
#    ' join',
#    ' beat',
#    ' violence',
#    ' gang member',
#    ' acquiescence',
#    ' opposes',
#    ' police officer',
#    ' organizations',
#    ' imputed',
#    ' leader',
#    ' conditions',
#    ' anti-gang',
#    ' ideology',
#    ' grounds',
#    ' removal',
#    ' arm',
#    ' political belief',
#    ' human rights',
#    ' disapproved',
#    ' qualify',
#    ' threats',
#    ' cases',
#    ' marks',
#    ' no evidence'],
#   'op_length': 63472},
#  {'name': 'Escobar-Del Cid v. Garland, 2022 U.S. App. LEXIS 6063',
#   'decision': 'denied',
#   'country': <re.Match object; span=(242, 5918), match='citizen of Guatemala, seeks review of a February >,
#   'terms': ['persecution',
#    ' threats',
#    ' well-founded',
#    ' objectively reasonable',
#    ' candidate',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' petition for review',
#    ' withholding',
#    ' quotation',
#    ' imminent',
#    ' removal',
#    ' marks',
#    ' political activity',
#    ' speculative',
#    ' conditions',
#    ' fulfilled',
#    ' concrete',
#    ' singled',
#    ' rising'],
#   'op_length': 5953},
#  {'name': 'Pinel-Gomez v. Garland, 52 F.4th 523',
#   'decision': 'denied',
#   'country': <re.Match object; span=(2417, 23070), match='citizens of Honduras. They left Honduras in April>,
#   'terms': ['corroborative evidence',
#    ' corroboration',
#    ' determinations',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' removal',
#    ' clear error',
#    ' withholding',
#    ' credibility',
#    ' credible testimony',
#    ' persecution',
#    ' de novo',
#    ' question of law',
#    ' Immigration',
#    ' gang',
#    ' documentation',
#    ' eligibility',
#    ' reasonably available',
#    ' standard of review',
#    ' factual findings',
#    ' de novo review',
#    ' fact finding',
#    ' quotation',
#    ' refugee',
#    ' threats',
#    ' marks'],
#   'op_length': 23103},
#  {'name': 'Gautam v. Barr, 832 Fed. Appx. 740',
#   'decision': 'denied',
#   'country': <re.Match object; span=(229, 6949), match='citizen of Nepal, seeks review of a May 21, 2018,>,
#   'terms': ['persecution',
#    ' relocate',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' humanitarian',
#    ' severe',
#    ' serious harm',
#    ' removal',
#    ' petition for review',
#    ' withholding',
#    ' lived',
#    ' beat',
#    ' substantial evidence to support',
#    ' preponderance of evidence',
#    " agency's determination",
#    ' factual basis',
#    ' no evidence',
#    ' seven years',
#    ' well-founded',
#    ' encountered',
#    ' unconscious',
#    ' occasions',
#    ' quotation',
#    ' effects',
#    ' reasons',
#    ' returns',
#    ' hiding',
#    ' safely',
#    ' fails',
#    ' marks',
#    ' join'],
#   'op_length': 7051},
#  {'name': 'Ojo v. Garland, 25 F.4th 152',
#   'decision': 'granted',
#   'country': <re.Match object; span=(3390, 101945), match='citizen of Nigeria, entered the United States on >,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' serious crime',
#    ' torture',
#    ' change of circumstances',
#    ' declaration',
#    " agency's decision",
#    ' circumstances',
#    ' vacates',
#    ' quotation',
#    ' marks',
#    ' legal standard',
#    ' deportee',
#    ' removal',
#    ' discretionary',
#    ' credible',
#    ' wire fraud',
#    ' persecution',
#    ' immigration',
#    ' withholding',
#    ' convicted',
#    ' alien',
#    ' eligibility',
#    ' remanding',
#    ' extraordinary circumstances',
#    ' conspiracy',
#    ' reasons',
#    ' piece of evidence',
#    ' criminal conduct',
#    ' discerned',
#    ' reviewing court'],
#   'op_length': 102210},
#  {'name': 'Enoh v. Barr, 794 Fed. Appx. 109',
#   'decision': 'granted',
#   'country': <re.Match object; span=(298, 7426), match='citizen of Cameroon, \xa0[*111]\xa0 seeks review >,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' conditions',
#    ' consolidated',
#    ' persecution',
#    ' motion to reopen'],
#   'op_length': 7602},
#  {'name': 'Hassan v. Barr, 821 Fed. Appx. 1',
#   'decision': 'granted',
#   'country': <re.Match object; span=(390, 14525), match='citizens of Bangladesh, and Sadid Hassan and Sama>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' credible',
#    ' persecution',
#    ' election',
#    ' motion to reopen',
#    ' violence',
#    ' removal',
#    ' withholding',
#    ' conditions',
#    ' reconsider',
#    ' reopen',
#    ' circumstances',
#    ' religious',
#    ' untimely',
#    ' alien'],
#   'op_length': 14705},
#  {'name': 'Kandel v. Barr, 832 Fed. Appx. 67',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 8239), match='citizen of Nepal, seeks review of an August 23, 2>,
#   'terms': ['persecution',
#    ' relocate',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>'],
#   'op_length': 8341},
#  {'name': 'Azmen v. Barr, 965 F.3d 128',
#   'decision': 'granted',
#   'country': <re.Match object; span=(608, 30965), match='citizen of Guatemala and a former member of the M>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' change of circumstances',
#    ' gang',
#    ' social group',
#    ' untimely',
#    ' circumstances',
#    ' particularity',
#    ' murder',
#    ' withholding',
#    ' eligibility',
#    ' quotation',
#    ' removal',
#    ' marks',
#    ' former gang member',
#    ' reasonable period',
#    ' deadline',
#    ' one-year',
#    ' gang member',
#    ' regulation',
#    ' decisions',
#    ' deference',
#    ' materially affect',
#    ' precedential'],
#   'op_length': 31038},
#  {'name': 'Cordova-Garcia v. Garland, 859 Fed. Appx. 587',
#   'decision': 'denied',
#   'country': <re.Match object; span=(345, 5688), match='citizens of Guatemala, seek review of a December >,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' persecution',
#    ' withholding',
#    ' removal',
#    ' petition for review',
#    ' former partner',
#    " daughter's",
#    ' membership',
#    ' violence',
#    ' waived',
#    ' nexus',
#    ' substantial evidence',
#    ' political opinion',
#    ' gang violence',
#    ' social group',
#    ' corroborate',
#    ' indigenous',
#    ' inflict',
#    ' rape'],
#   'op_length': 5790},
#  {'name': 'Garcia-Aranda v. Garland, 2022 U.S. App. LEXIS 32020',
#   'decision': 'granted',
#   'country': <re.Match object; span=(274, 24060), match='citizen of Honduras, testified before an Immigrat>,
#   'terms': ['gang',
#    ' torture',
#    ' removal',
#    ' acquiescence',
#    ' withholding',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' police officer',
#    ' public official',
#    ' color of law',
#    ' social group',
#    ' kidnapping',
#    ' targeted',
#    ' drug trafficking',
#    ' membership',
#    ' official capacity',
#    ' blind'],
#   'op_length': 24146},
#  {'name': 'Gurung v. Barr, 824 Fed. Appx. 27',
#   'decision': 'denied',
#   'country': <re.Match object; span=(255, 8566), match='citizens of Nepal, seek review of a May 25, 2018,>,
#   'terms': ['persecution',
#    ' objectively reasonable',
#    ' violence',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>'],
#   'op_length': 8668},
#  {'name': 'Hoque v. Barr, 824 Fed. Appx. 21',
#   'decision': 'denied',
#   'country': <re.Match object; span=(234, 6313), match='citizen of Bangladesh, seeks review of an April 3>,
#   'terms': ['inconsistency',
#    ' credibility',
#    ' credibility determinations',
#    ' corroborate',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' consistency',
#    ' interview',
#    ' totality of the circumstances',
#    ' petition for review',
#    ' rehabilitate',
#    ' reliable',
#    ' harmed',
#    ' memory',
#    ' documentary evidence',
#    ' substantial evidence',
#    ' relevant factors',
#    ' fact-finder',
#    ' withholding',
#    ' removal',
#    ' threats',
#    ' alien',
#    ' defer',
#    ' beat'],
#   'op_length': 6415},
#  {'name': 'Chen Hua v. Wilkinson, 847 Fed. Appx. 20',
#   'decision': 'denied',
#   'country': <re.Match object; span=(220, 10096), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['persecution',
#    ' church',
#    ' credibility',
#    ' unregistered',
#    ' inconsistency',
#    ' grandmother',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' arrest',
#    ' attendance',
#    ' maternal'],
#   'op_length': 10193},
#  {'name': 'Singh v. Garland, 11 F.4th 106',
#   'decision': 'denied',
#   'country': <re.Match object; span=(813, 29144), match='citizen of India who arrived in Hildago, Texas, o>,
#   'terms': ['persecution',
#    ' relocate',
#    ' removal',
#    ' torture',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' safely',
#    ' political party',
#    ' withholding',
#    ' well-founded',
#    ' alien',
#    ' rival',
#    ' country-conditions',
#    ' circumstances',
#    ' authorities',
#    ' immigration',
#    ' membership',
#    ' mistreatment',
#    ' nationality',
#    ' phone'],
#   'op_length': 29452},
#  {'name': 'Banegas-Suquilanda v. Barr, 829 Fed. Appx. 544',
#   'decision': 'denied',
#   'country': <re.Match object; span=(245, 8718), match='citizen of Ecuador, seeks review of a BIA decisio>,
#   'terms': ['omissions',
#    ' credibility',
#    ' inconsistency',
#    ' credibility determinations',
#    ' discrepancies',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>'],
#   'op_length': 8820},
#  {'name': 'Kalala v. Barr, 804 Fed. Appx. 48',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 6350), match='citizen of the Democratic Republic of the Congo, >,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' interview',
#    ' credibility determinations',
#    ' credibility',
#    ' fact-finder',
#    ' quotation',
#    ' marks',
#    ' inconsistencies',
#    ' persecution',
#    ' petition for review',
#    ' consistency',
#    ' falsehoods',
#    ' answers',
#    ' defer',
#    ' substantial evidence to support',
#    ' totality of the circumstances',
#    " applicant's claim",
#    ' relevant factors',
#    ' take care',
#    ' inaccuracies',
#    ' corroborate',
#    ' withholding',
#    ' passport',
#    ' reliable',
#    ' removal',
#    ' staying',
#    ' harmed',
#    ' flee',
#    ' goes',
#    ' rape'],
#   'op_length': 6452},
#  {'name': 'Likai Gao v. Barr, 968 F.3d 137',
#   'decision': 'denied',
#   'country': <re.Match object; span=(60, 26083), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['credibility',
#    ' inconsistencies',
#    ' gatherings',
#    ' church',
#    ' arrest',
#    ' removal',
#    ' religious',
#    ' attending',
#    ' written statement',
#    ' demeanor',
#    ' persecution',
#    ' hosting',
#    ' credibility determinations',
#    ' assessing',
#    ' alien',
#    ' discrepancy',
#    ' factfinder',
#    ' interrogated',
#    ' detention',
#    ' started',
#    ' petition for review',
#    ' religious freedom',
#    ' immigration',
#    ' questions',
#    ' reasons',
#    ' argues',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' direct examination',
#    ' freedom of speech',
#    ' corroborative'],
#   'op_length': 26116},
#  {'name': 'Scarlett v. Barr, 957 F.3d 316',
#   'decision': None,
#   'country': <re.Match object; span=(2495, 50952), match='citizen of Jamaica who, for fifteen years, served>,
#   'terms': ['persecution',
#    ' gang',
#    ' withholding',
#    ' torture',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' acquiescence',
#    ' authorities',
#    ' unwilling',
#    ' violence',
#    ' removal',
#    ' gang violence',
#    ' feared',
#    ' unwilling-or-unable',
#    ' quotation',
#    ' reopen',
#    ' marks',
#    ' helplessness',
#    ' fail to demonstrate',
#    ' threats',
#    ' police officer',
#    ' alien',
#    ' extraordinary circumstances',
#    ' ineffectiveness',
#    ' circumstances',
#    ' squad',
#    ' kill',
#    ' gang member',
#    ' proceedings',
#    ' condoned',
#    ' government official'],
#   'op_length': 50952},
#  {'name': 'Singh v. Barr, 809 Fed. Appx. 19',
#   'decision': 'denied',
#   'country': <re.Match object; span=(255, 8625), match='citizen of India, seeks review of a June 29, 2018>,
#   'terms': ['credibility determinations',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' circumstances',
#    ' demeanor',
#    ' credibility'],
#   'op_length': 8767},
#  {'name': 'Macas-Moreno v. Garland, 852 Fed. Appx. 22',
#   'decision': 'denied',
#   'country': <re.Match object; span=(238, 6462), match='citizen of Ecuador, seeks review of a November 1,>,
#   'terms': ['torture',
#    ' removal',
#    ' social group',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' withholding',
#    ' petition for review',
#    ' police officer',
#    ' persecution',
#    ' summary denial',
#    ' eligibility',
#    ' quotation',
#    ' suffering',
#    ' witnesses',
#    ' exhaust',
#    ' inhuman',
#    ' merits',
#    ' severe',
#    ' cruel',
#    ' marks',
#    ' nexus',
#    ' pain'],
#   'op_length': 6564},
#  {'name': 'Lin v. Garland, 2021 U.S. App. LEXIS 28296',
#   'decision': 'denied',
#   'country': <re.Match object; span=(220, 15482), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['credibility',
#    ' credibility determinations',
#    ' inconsistency',
#    ' aunt',
#    ' corroborate',
#    ' interpreter',
#    ' evasive',
#    ' documents',
#    ' petition for review',
#    ' burden of proof'],
#   'op_length': 15517},
#  {'name': "Khalilur Rahman v. United States Dep't of Homeland Sec., 2022 U.S. Dist. LEXIS 54269",
#   'decision': 'granted',
#   'country': None,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' immigration',
#    ' res judicata',
#    ' inadmissible',
#    ' permanent resident',
#    ' litigated',
#    ' preclusion',
#    ' terrorism',
#    ' grounds',
#    ' terrorist organization',
#    ' collateral estoppel',
#    ' immigration judge',
#    ' terrorism-related',
#    ' terrorist activity',
#    ' proceedings',
#    ' motion to dismiss',
#    ' membership',
#    ' asylee',
#    ' links',
#    ' subclause',
#    ' prior proceedings',
#    ' summary judgment',
#    ' determinations',
#    ' allegations',
#    ' terrorist',
#    ' join'],
#   'op_length': 24626},
#  {'name': 'Almendades v. Garland, 853 Fed. Appx. 727',
#   'decision': 'granted',
#   'country': <re.Match object; span=(1855, 9922), match='citizen of El Salvador. As evidence of alienage, >,
#   'terms': ['alienage',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' proceedings',
#    ' interview',
#    ' reliable',
#    ' records'],
#   'op_length': 9972},
#  {'name': 'United States v. Dumitru, 991 F.3d 427',
#   'decision': None,
#   'country': None,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' enhancement',
#    ' aggravated',
#    ' identity theft',
#    ' identification',
#    ' sentence',
#    ' district court',
#    ' counts',
#    ' identify information',
#    ' lawful authority',
#    ' Guidelines',
#    ' immigration',
#    ' narratives',
#    ' convicted',
#    ' documents',
#    ' preparing',
#    ' staff',
#    ' false statement',
#    ' fraudulent',
#    ' indictment',
#    ' knowingly',
#    ' insufficient evidence',
#    ' statutory violation',
#    ' imprisonment',
#    ' consecutive',
#    ' persecution',
#    ' nine-level',
#    ' signatures'],
#   'op_length': 25962},
#  {'name': 'Bhaktibhai-Patel v. Garland, 32 F.4th 180',
#   'decision': None,
#   'country': <re.Match object; span=(761, 48729), match='citizen of India, was ordered removed from the Un>,
#   'terms': ['alien',
#    ' removal',
#    ' reinstatement',
#    ' order of removal',
#    ' reentrants',
#    ' withholding-only',
#    ' final order',
#    ' judicial review',
#    ' proceedings',
#    ' withholding',
#    ' removal order',
#    ' prior order',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' immigration',
#    ' decisions',
#    ' immigration judge',
#    ' persecution',
#    ' deportation',
#    ' torture',
#    ' reasonable fear',
#    ' reentered',
#    ' rights',
#    ' petition for review',
#    ' question of law',
#    ' challenges',
#    ' quotation',
#    ' courts',
#    ' marks',
#    ' immigration officer',
#    ' eligibility'],
#   'op_length': 48779},
#  {'name': 'Balasegarathum v. Barr, 827 Fed. Appx. 90',
#   'decision': 'denied',
#   'country': <re.Match object; span=(243, 11260), match='citizen of Sri Lanka, seeks review of a BIA decis>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' persecution',
#    ' corroborate',
#    ' credibility determinations',
#    ' seeker',
#    ' credibility',
#    ' conditions',
#    ' returning',
#    ' abuses'],
#   'op_length': 11362},
#  {'name': 'Fremont v. Barr, 824 Fed. Appx. 51',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 13731), match='citizen of Haiti, seeks review of a January 15, 2>,
#   'terms': ['corroboration',
#    ' persecution',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' proceedings',
#    ' competency',
#    ' clear and convincing evidence',
#    ' Immigration',
#    ' safeguards',
#    ' petition for review',
#    ' conviction record',
#    ' political opinion',
#    ' five year',
#    ' alien'],
#   'op_length': 13833},
#  {'name': 'De Artiga v. Barr, 961 F.3d 586',
#   'decision': 'granted',
#   'country': <re.Match object; span=(1242, 30398), match='citizen of El Salvador. Martinez seeks relief fro>,
#   'terms': ['torture',
#    ' gang',
#    ' threats',
#    ' killed',
#    ' gang member',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' withholding',
#    ' recruitment',
#    ' removal',
#    ' targeted',
#    ' violence',
#    ' membership',
#    ' harmed',
#    ' political opinion',
#    ' matter of law',
#    ' physical harm',
#    ' social group',
#    ' harassment',
#    ' campaign',
#    ' credible',
#    ' futile',
#    ' violent confrontation',
#    ' petition for review',
#    ' summary denial',
#    ' confidently',
#    ' interfering',
#    ' whereabouts',
#    ' encounter',
#    ' inflicted',
#    ' suffering'],
#   'op_length': 30436},
#  {'name': 'Kaijun Hu v. Barr, 813 Fed. Appx. 8',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 5971), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['persecution',
#    ' motion to reopen',
#    ' circumstances',
#    ' fundamental change',
#    ' well-founded',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' petition for review',
#    ' family planning',
#    ' authorities',
#    ' removal',
#    ' reopen',
#    ' rebut a presumption',
#    ' prima facie case',
#    ' future harm',
#    ' seek review',
#    ' withholding',
#    ' conditions',
#    ' undertaken',
#    ' affirming',
#    ' reasons'],
#   'op_length': 6083},
#  {'name': 'Quintanilla-Mejia v. Garland, 3 F.4th 569',
#   'decision': 'denied',
#   'country': <re.Match object; span=(83, 55054), match='citizen of El Salvador who has unlawfully entered>,
#   'terms': ['gang',
#    ' social group',
#    ' removal',
#    ' credibility',
#    ' withholding',
#    ' torture',
#    ' gang member',
#    ' acquiescence',
#    ' beat',
#    ' membership',
#    ' former gang member',
#    ' interview',
#    ' rehabilitate',
#    ' tattoos',
#    ' alien',
#    ' government official',
#    ' persecution',
#    ' religion',
#    ' kill',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' youth',
#    ' cognizable',
#    ' church',
#    ' reasonable fear',
#    ' particularity',
#    " persecutor's",
#    ' joining',
#    ' resist',
#    ' burden of proof',
#    ' gang violence'],
#   'op_length': 55182},
#  {'name': 'United States v. Greenberg, 2022 U.S. Dist. LEXIS 47993',
#   'decision': 'denied',
#   'country': <re.Match object; span=(3362, 101629), match='citizens from Russia, Ukraine, and nearby countri>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' indictment',
#    ' conspiracy',
#    ' immigration',
#    ' interview',
#    ' superseding',
#    ' argues',
#    ' blog',
#    ' fraudulent',
#    ' duplicitous',
#    ' conspired',
#    ' severance',
#    ' prepare',
#    ' defraud',
#    ' first paragraph',
#    ' recording',
#    ' rights',
#    ' cooperating',
#    ' suppress',
#    ' Reply',
#    ' proceedings',
#    ' authentic',
#    ' documents',
#    ' alleges',
#    ' procured',
#    ' waived',
#    ' motion to dismiss',
#    ' false statement',
#    ' single count',
#    ' counterfeiting'],
#   'op_length': 101702},
#  {'name': 'Baisheng Chen v. Wolf, 2020 U.S. Dist. LEXIS 217805',
#   'decision': 'granted',
#   'country': <re.Match object; span=(572, 29771), match='citizen of China, alleges that while in China, he>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' provisions',
#    ' subject matter jurisdiction',
#    ' courts',
#    ' unreasonable delay',
#    ' rule of reason',
#    ' delays',
#    ' motion to dismiss',
#    ' adjudicate',
#    ' alleges',
#    ' factors',
#    ' clear right',
#    ' quotation',
#    ' marks',
#    ' legally enforceable',
#    ' pro-democracy',
#    ' authorities',
#    ' processing',
#    ' timeframes',
#    ' mandamus',
#    ' agrees'],
#   'op_length': 29844},
#  {'name': 'De Oliveira v. Barr, 2020 U.S. Dist. LEXIS 71025',
#   'decision': None,
#   'country': <re.Match object; span=(1215, 18856), match='citizens to apply for asylum. § 8 U.S.C. 1158(a).>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' district court',
#    ' processing',
#    ' subject matter jurisdiction',
#    ' delayed',
#    ' mandamus',
#    ' private right of action',
#    " agency's action",
#    " defendants'",
#    ' adjudicate',
#    ' provisions',
#    ' quotations'],
#   'op_length': 18945},
#  {'name': 'Ying Yu Liu v. Wolf, 2020 U.S. Dist. LEXIS 95456',
#   'decision': None,
#   'country': <re.Match object; span=(1420, 33142), match='citizens of the People\'s Republic of China. Afte>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' subject matter jurisdiction',
#    ' alleges',
#    ' adjudicate',
#    ' interview',
#    ' scheduled',
#    ' unreasonable delay',
#    ' mandamus',
#    ' delayed',
#    ' cases',
#    ' reasonable time',
#    ' forcibly',
#    ' district court',
#    ' rule of reason',
#    ' sterilized',
#    ' alien',
#    ' federal question',
#    " agency's action",
#    ' authorization',
#    ' Immigration',
#    ' quotations',
#    ' processes',
#    ' timetable',
#    ' filings',
#    ' waiting',
#    ' Courts',
#    ' factual allegations',
#    ' legally enforceable',
#    ' motion to dismiss',
#    ' derivative'],
#   'op_length': 33237},
#  {'name': 'Ruan v. Wolf, 2020 U.S. Dist. LEXIS 23559',
#   'decision': None,
#   'country': <re.Match object; span=(1181, 22698), match='citizens present in the United States are permitt>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' USCIS',
#    ' adjudicated',
#    ' motion to dismiss',
#    " agency's action",
#    ' delayed',
#    ' unreasonable delay',
#    ' allegations',
#    ' scheduling',
#    ' interview',
#    ' Expedite',
#    ' courts',
#    ' judicial review',
#    ' rule of reason',
#    ' three year',
#    " defendants'",
#    ' waiting',
#    ' subject matter jurisdiction',
#    ' cause of action',
#    ' authorization',
#    ' backlog',
#    ' factors'],
#   'op_length': 22707},
#  {'name': 'Garcia v. Barr, 2020 U.S. Dist. LEXIS 17173',
#   'decision': None,
#   'country': <re.Match object; span=(800, 55178), match='citizen of Honduras. (Dkt. 4-1 at ¶ 4). He illega>,
#   'terms': ['alien',
#    ' detention',
#    ' detained',
#    ' immigration',
#    ' parole',
#    ' removal',
#    ' proceedings',
#    ' due process',
#    ' arriving',
#    ' courts',
#    ' burden of proof',
#    ' prolonged',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' discretionary',
#    ' exhaustion',
#    ' quotation',
#    ' credible',
#    ' erroneous deprivation',
#    ' custody',
#    ' argues',
#    ' clear and convincing evidence',
#    ' due process protection',
#    ' reasons',
#    ' border',
#    ' persecution',
#    ' designated',
#    ' instant matter',
#    ' flight risk',
#    ' continuance',
#    ' detainee'],
#   'op_length': 55187},
#  {'name': 'Zhang v. Wolf, 2020 U.S. Dist. LEXIS 183337',
#   'decision': None,
#   'country': <re.Match object; span=(4355, 24928), match='citizens of the People\'s Republic of China. Comp>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' USCIS',
#    ' adjudicate',
#    ' courts',
#    ' motion to dismiss',
#    ' rule of reason',
#    ' backlog',
#    ' judicial review',
#    ' stripping',
#    ' timeline',
#    ' subject matter jurisdiction',
#    ' unreasonable delay',
#    ' circumstances',
#    ' immigration',
#    ' lack of subject matter jurisdiction',
#    ' fail to state a claim',
#    ' declaratory judgment',
#    " agency's action",
#    " Defendants'",
#    ' allegations',
#    ' processing',
#    ' quotation',
#    ' factors',
#    ' delays',
#    ' marks'],
#   'op_length': 25003},
#  {'name': 'Rodriguez-Figueroa v. Barr, 442 F. Supp. 3d 549',
#   'decision': None,
#   'country': <re.Match object; span=(802, 47779), match='citizen of Honduras. (Dkt. 8-1 at ¶ 5). He illega>,
#   'terms': ['alien',
#    ' detention',
#    ' detained',
#    ' immigration',
#    ' removal',
#    ' parole',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' burden of proof',
#    ' arriving',
#    ' courts',
#    ' exhaustion',
#    ' prolonged',
#    ' custody',
#    ' due process',
#    ' proceedings',
#    ' credible',
#    ' border',
#    ' clear and convincing evidence',
#    ' erroneous deprivation',
#    ' persecution',
#    ' argues',
#    ' flight',
#    ' discretionary',
#    ' continuance',
#    ' designated',
#    ' reasons',
#    ' detention facility',
#    ' challenges',
#    ' quotation',
#    ' estoppel'],
#   'op_length': 47788},
#  {'name': 'Ramirez v. Decker, 2020 U.S. Dist. LEXIS 59605',
#   'decision': 'denied',
#   'country': <re.Match object; span=(7941, 58167), match='citizen of Guatemala born on December 14, 2000. D>,
#   'terms': ['alien',
#    ' custody',
#    ' detention',
#    ' arriving',
#    ' immigration',
#    ' unaccompanied',
#    ' Sponsor',
#    ' statutory definition',
#    ' physical custody',
#    ' due process',
#    ' least restrictive',
#    ' detained',
#    ' parole',
#    ' removal proceedings',
#    ' provide care',
#    ' arrested',
#    ' transferred',
#    ' argues',
#    ' legal guardian',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' border',
#    ' ceased',
#    ' authorization',
#    ' discretionary',
#    ' immigration status',
#    ' due process right',
#    ' mandatory',
#    ' placement',
#    ' quotation',
#    ' continued detention'],
#   'op_length': 58286},
#  {'name': 'Doe v. East Side Club, LLC, 2021 U.S. Dist. LEXIS 123497',
#   'decision': 'granted',
#   'country': None,
#   'terms': ["Defendants'",
#    ' sanctions',
#    ' discovery',
#    ' deposition',
#    ' providers',
#    ' emotional distress',
#    ' documents',
#    ' misrepresentations',
#    ' damages',
#    ' emotional distress damages',
#    ' parties',
#    ' disclosure',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' defense counsel',
#    ' obstruction',
#    ' disclose',
#    ' lawsuit',
#    ' sur-reply',
#    ' motion for sanctions',
#    ' misconduct',
#    ' conceal',
#    ' instant motion',
#    ' records',
#    ' motion in limine',
#    ' suffering',
#    ' motion to compel',
#    ' medical record',
#    ' bad faith',
#    ' psychiatric',
#    ' cases'],
#   'op_length': 86587},
#  {'name': 'Singh v. Barr, 2020 U.S. Dist. LEXIS 38652',
#   'decision': None,
#   'country': <re.Match object; span=(1032, 39011), match='citizen of India. (Dkt. 5-1 at ¶ 5). He illegally>,
#   'terms': ['alien',
#    ' detention',
#    ' detained',
#    ' removal',
#    ' immigration',
#    ' burden of proof',
#    ' prolonged',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' courts',
#    ' parole',
#    ' due process',
#    ' flight',
#    ' arriving',
#    ' custody',
#    ' clear and convincing evidence',
#    ' erroneous deprivation',
#    ' persecution',
#    ' proceedings',
#    ' exhaustion',
#    ' border',
#    ' removal proceedings',
#    ' designated',
#    ' credible',
#    ' factors',
#    ' weighs',
#    ' substantive due process',
#    ' due process protection',
#    ' immigration officer',
#    ' immediate release',
#    ' deportation'],
#   'op_length': 39020},
#  {'name': 'Mei Bin Zheng v. Barr, 829 Fed. Appx. 536',
#   'decision': 'granted',
#   'country': <re.Match object; span=(174, 7978), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['nationality',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' withholding',
#    ' removal',
#    ' ineffective assistance of counsel',
#    ' persecution',
#    ' alien'],
#   'op_length': 8182},
#  {'name': 'Nagahama v. Garland, 2022 U.S. App. LEXIS 33013',
#   'decision': 'granted',
#   'country': <re.Match object; span=(271, 7233), match='citizen of Peru, seeks review of a May 21, 2020, >,
#   'terms': ['circumstances',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' persecution',
#    ' torture',
#    ' withholding',
#    ' removal'],
#   'op_length': 7476},
#  {'name': 'Nazarov v. Garland, 2021 U.S. App. LEXIS 33593',
#   'decision': 'denied',
#   'country': <re.Match object; span=(260, 8058), match='citizens of Uzbekistan, seek review of a July 24,>,
#   'terms': ['persecution',
#    ' tortured',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' lender',
#    ' withholding',
#    ' well-founded',
#    ' confiscated',
#    ' removal',
#    ' exit'],
#   'op_length': 8160},
#  {'name': 'Niang v. Barr, 826 Fed. Appx. 12',
#   'decision': 'denied',
#   'country': <re.Match object; span=(229, 6659), match='citizen of Senegal, seeks review of a May 18, 201>,
#   'terms': ['credibility',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' credibility determinations',
#    ' corroboration',
#    ' inconsistencies',
#    ' totality of the circumstances',
#    ' petition for review',
#    ' consistency',
#    ' persecution',
#    ' omission',
#    ' reliable',
#    ' cousin',
#    ' vague',
#    ' substantial evidence to support',
#    ' immigration judge',
#    ' relevant factors',
#    ' reasonably rely',
#    ' family friend',
#    ' circumstances',
#    ' descriptions',
#    ' inaccuracies',
#    ' rehabilitate',
#    ' allegations',
#    ' withholding',
#    ' falsehood',
#    ' attacked',
#    ' details',
#    ' removal',
#    ' harass',
#    ' defer'],
#   'op_length': 6761},
#  {'name': 'Oliva-Oliva v. Garland, 2022 U.S. App. LEXIS 21281',
#   'decision': 'granted',
#   'country': <re.Match object; span=(266, 6655), match='citizen of Guatemala, seeks review of a March 24,>,
#   'terms': ['gang',
#    ' removal',
#    ' political opinion',
#    ' withholding',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' persecution',
#    ' quotation',
#    ' torture',
#    ' marks',
#    ' acquiescence',
#    ' petition for review',
#    ' conditions',
#    ' targeted',
#    ' relevant evidence',
#    ' disapproves',
#    ' eligibility',
#    ' imputation',
#    ' persecutor',
#    ' nexus'],
#   'op_length': 6785},
#  {'name': 'Pan v. Barr, 808 Fed. Appx. 31',
#   'decision': 'denied',
#   'country': <re.Match object; span=(223, 7536), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['persecution',
#    ' credibility determinations',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' church',
#    ' credibility',
#    ' demeanor',
#    ' substantial evidence',
#    ' petition for review',
#    ' well-founded',
#    ' consistency',
#    ' corroborate',
#    ' removal',
#    ' arrest',
#    ' region',
#    ' defer',
#    ' totality of the circumstances',
#    ' objectively reasonable',
#    ' similarly situated',
#    ' relevant factors',
#    ' observations',
#    ' rehabilitate',
#    ' authorities',
#    ' eligibility',
#    ' underground',
#    ' withholding',
#    ' shifted',
#    ' raid'],
#   'op_length': 7638},
#  {'name': 'Patel-Nirav v. Garland, 2021 U.S. App. LEXIS 38034',
#   'decision': 'denied',
#   'country': <re.Match object; span=(229, 4940), match='citizen of India, seeks review of a January 28, 2>,
#   'terms': ['credibility',
#    ' credibility determinations',
#    ' inconsistency',
#    ' corroboration',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' petition for review',
#    ' totality of the circumstances',
#    ' inconsistent statement',
#    ' substantial evidence',
#    ' relevant factors',
#    ' reasonably rely',
#    ' second attack',
#    ' first attack',
#    ' rehabilitate',
#    ' consistency',
#    ' fact-finder',
#    ' withholding',
#    ' injuries',
#    ' omission',
#    ' removal'],
#   'op_length': 5042},
#  {'name': 'Ramirez-Hernandez v. Garland, 2022 U.S. App. LEXIS 17747',
#   'decision': 'granted',
#   'country': <re.Match object; span=(269, 8251), match='citizen of Guatemala, seeks review of a July 17, >,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' social group',
#    ' withholding',
#    ' removal',
#    ' gang member',
#    ' persecution',
#    ' membership'],
#   'op_length': 8493},
#  {'name': 'Regmi v. Barr, 832 Fed. Appx. 744',
#   'decision': 'denied',
#   'country': <re.Match object; span=(229, 7601), match='citizen of Nepal, seeks review of a July 16 2018,>,
#   'terms': ['persecution',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' humanitarian',
#    ' conditions'],
#   'op_length': 7710},
#  {'name': 'Selvaraj v. Garland, 2022 U.S. App. LEXIS 26491',
#   'decision': 'granted',
#   'country': <re.Match object; span=(259, 12123), match='citizen of Sri Lanka, seeks review of a February >,
#   'terms': ['persecution',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' credibility',
#    ' torture',
#    ' credibility determinations',
#    ' seeker',
#    ' omissions'],
#   'op_length': 12220},
#  {'name': 'Sherpa v. Barr, 837 Fed. Appx. 826',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 6902), match='citizen of Nepal, seeks review of an October 11, >,
#   'terms': ['persecution',
#    ' conditions',
#    ' violence',
#    ' relocate',
#    ' fundamental change',
#    ' elections',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' safely',
#    ' objectively reasonable',
#    ' petition for review',
#    ' circumstances',
#    ' well-founded',
#    ' withholding',
#    ' decrease',
#    ' removal',
#    ' rebut',
#    ' preponderance of evidence',
#    ' administrative notice',
#    " agency's finding",
#    ' change condition',
#    ' question of law',
#    ' fail to meet',
#    ' insurgency',
#    ' extortion',
#    ' targeting',
#    ' unharmed',
#    ' faction',
#    ' lived'],
#   'op_length': 7004},
#  {'name': 'Singh v. Barr, 801 Fed. Appx. 819',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 9413), match='citizen of India, seeks review of a July 10, 2018>,
#   'terms': ['persecution', ' credible', ' corroborating', ' beating'],
#   'op_length': 9531},
#  {'name': 'Singh v. Barr, 828 Fed. Appx. 31',
#   'decision': 'denied',
#   'country': <re.Match object; span=(228, 6021), match='citizen of India, seeks review of a May 2, 2018, >,
#   'terms': ['credibility determinations',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' inconsistencies',
#    ' credibility',
#    ' petition for review',
#    ' consistency',
#    ' dramatically different',
#    ' inconsistent statement',
#    ' substantial evidence',
#    ' relevant factors',
#    ' threaten to kill',
#    ' circumstances',
#    ' fact-finder',
#    ' withholding',
#    ' interview',
#    ' traveled',
#    ' exhaust',
#    ' removal',
#    ' fled'],
#   'op_length': 6056},
#  {'name': 'Singh v. Barr, 832 Fed. Appx. 81',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 7587), match='citizen of India, seeks review of a November 30, >,
#   'terms': ['threats',
#    ' credibility determinations',
#    ' credibility',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>'],
#   'op_length': 7689},
#  {'name': 'Singh v. Garland, 6 F.4th 418',
#   'decision': 'granted',
#   'country': <re.Match object; span=(59, 29182), match='citizen of India seeking relief from least not of>,
#   'terms': ['inconsistency',
#    ' credibility',
#    ' credibility finding',
#    ' omission',
#    ' persecution',
#    ' conversations',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' beatings',
#    ' substantial evidence',
#    ' beaten',
#    ' attacks',
#    ' police station',
#    ' second attack',
#    ' accompanied',
#    ' reasons',
#    ' trivial',
#    ' bases',
#    ' credibility determinations',
#    ' mercilessly',
#    ' fabricated',
#    ' undermined',
#    ' quotation',
#    ' grounds',
#    ' marks',
#    ' reviewing court',
#    ' circumstances',
#    ' post-attack',
#    ' aftermath',
#    ' casting',
#    ' adhere'],
#   'op_length': 29266},
#  {'name': 'Singh v. Garland, 2022 U.S. App. LEXIS 5469',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 7487), match='citizen of India, seeks review of an August 23, 2>,
#   'terms': ['persecution',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' humanitarian',
#    ' severity',
#    ' removal'],
#   'op_length': 7589},
#  {'name': 'Sunar v. Garland, 2022 U.S. App. LEXIS 29495',
#   'decision': 'denied',
#   'country': <re.Match object; span=(228, 7174), match='citizen of Nepal, seeks review of an October 22, >,
#   'terms': ['persecution',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' well-founded',
#    ' withholding',
#    ' removal',
#    ' bomb',
#    ' petition for review',
#    ' detonated',
#    ' beating',
#    ' target',
#    ' objectively reasonable',
#    ' political activity',
#    ' family member',
#    ' circumstances',
#    ' credibility',
#    ' departure',
#    ' quotation',
#    ' attacked',
#    ' harmed',
#    ' nearby',
#    ' marks'],
#   'op_length': 7276},
#  {'name': 'Tamang v. Garland, 2022 U.S. App. LEXIS 18247',
#   'decision': 'denied',
#   'country': <re.Match object; span=(230, 6563), match='citizen of Nepal, seeks review of an October 10, >,
#   'terms': ['persecution',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' village',
#    ' objectively reasonable',
#    ' petition for review',
#    ' well-founded',
#    ' contacted',
#    ' assault',
#    ' two year',
#    ' adjudicator',
#    ' withholding',
#    ' harassment',
#    ' quotation',
#    ' unharmed',
#    ' removal',
#    ' native',
#    ' rising',
#    ' marks'],
#   'op_length': 6665},
#  {'name': 'Thanasi v. Garland, 850 Fed. Appx. 109',
#   'decision': 'denied',
#   'country': <re.Match object; span=(214, 6986), match='citizen of Albania, seeks review of a March 13, 2>,
#   'terms': ['credibility determinations',
#    ' credibility',
#    ' omission',
#    ' Visa',
#    ' petition for review',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' inconsistencies',
#    ' persecution',
#    ' substantial evidence',
#    ' credibility finding',
#    ' material omission',
#    ' factual findings',
#    ' reasonable basis',
#    ' reasonably rely',
#    " third-parties'",
#    ' fraudulent',
#    ' quotation',
#    ' witnessed',
#    ' demeanor',
#    ' removal',
#    ' beaten',
#    ' marks'],
#   'op_length': 7088},
#  {'name': 'Wu v. Garland, 2022 U.S. App. LEXIS 6069',
#   'decision': 'denied',
#   'country': <re.Match object; span=(250, 8179), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['credibility determinations',
#    ' church',
#    ' inconsistencies',
#    ' demeanor',
#    ' credibility',
#    ' attended',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>'],
#   'op_length': 8267},
#  {'name': 'Xue Kui Zheng v. Garland, 2022 U.S. App. LEXIS 28321',
#   'decision': 'denied',
#   'country': <re.Match object; span=(221, 7552), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' removal',
#    ' Immigration',
#    ' persecution',
#    ' notice'],
#   'op_length': 7624},
#  {'name': 'Yi Lun Wang v. Garland, 857 Fed. Appx. 679',
#   'decision': 'denied',
#   'country': <re.Match object; span=(223, 7124), match='citizen of the People\'s Republic of China, \xa0[>,
#   'terms': ['persecution',
#    ' well-founded',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' removal',
#    ' petition for review',
#    ' similarly situated',
#    ' communications',
#    ' withholding',
#    ' religious',
#    ' church',
#    ' reasonable possibility',
#    ' religious practice',
#    ' political opinion',
#    ' local official',
#    ' eligibility',
#    ' nationality',
#    ' quotation',
#    ' religion',
#    ' Imputed',
#    ' native',
#    ' online',
#    ' varied',
#    ' fails',
#    ' marks'],
#   'op_length': 7235},
#  {'name': 'Yuan Lan Shi v. Barr, 808 Fed. Appx. 38',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 6445), match='citizen of China, seeks review of a July 17, 2018>,
#   'terms': ['<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' credibility determinations',
#    ' omission',
#    ' notices',
#    ' corroboration',
#    ' credibility',
#    ' totality of the circumstances',
#    ' substantial evidence',
#    ' petition for review',
#    ' inconsistency',
#    ' consistency',
#    ' interested witness',
#    ' relevant factors',
#    ' family member',
#    ' per curiam',
#    ' cross-examination',
#    ' rehabilitate',
#    ' authorities',
#    ' fact-finder',
#    ' withholding',
#    ' inspection',
#    ' disclose',
#    ' reliable',
#    " alien's",
#    ' letters',
#    ' removal',
#    ' defer',
#    ' goes'],
#   'op_length': 6547},
#  {'name': 'Wenting Huang v. Barr, 819 Fed. Appx. 8',
#   'decision': 'denied',
#   'country': <re.Match object; span=(225, 6637), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['demeanor',
#    ' credibility determinations',
#    ' inconsistencies',
#    ' credibility',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' petition for review',
#    ' due process',
#    ' corroboration',
#    ' Immigration',
#    ' translated',
#    ' detention',
#    ' quotation',
#    ' church',
#    ' marks',
#    ' totality of the circumstances',
#    ' relevant factors',
#    ' reasonably rely',
#    ' rehabilitate',
#    ' consistency',
#    ' fact-finder',
#    ' proceedings',
#    ' withholding',
#    ' attending',
#    ' removal',
#    ' defer',
#    ' trier'],
#   'op_length': 6739},
#  {'name': 'Abid v. Barr, 839 Fed. Appx. 624',
#   'decision': 'denied',
#   'country': <re.Match object; span=(231, 12108), match='citizen of Pakistan, seeks review of a January 24>,
#   'terms': ['interview',
#    ' credible',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' inconsistencies',
#    ' questions',
#    ' reliable',
#    ' credibility determinations',
#    ' omission',
#    ' border',
#    ' interpreter'],
#   'op_length': 12210},
#  {'name': 'Argueta v. Garland, 2022 U.S. App. LEXIS 31490',
#   'decision': 'denied',
#   'country': <re.Match object; span=(298, 6807), match='citizens of El Salvador, seek review of a March 6>,
#   'terms': ['persecution',
#    ' removal',
#    ' gang',
#    ' withholding',
#    ' <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>',
#    ' political opinion',
#    ' social group',
#    ' gang member',
#    ' membership',
#    ' targeted',
#    ' torture',
#    ' rapist',
#    ' substantial evidence',
#    ' petition for review',
#    ' eldest son',
#    ' acquiescence',
#    ' nationality',
# ...
#    ' habeas relief',
#    ' Immigration',
#    ' anonymously',
#    ' factors',
#    ' corpus',
#    ' rights'],
#   'op_length': 23142},
#  {'name': 'Doucoure v. Barr, 839 Fed. Appx. 609',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 3929), match='citizen of Mauritania, seeks review of a Septembe>,
#   'terms': ['anti-slavery',
#    ' motion to reopen',
#    ' conditions',
#    ' reopen',
#    ' petition for review',
#    ' material change',
#    ' proceedings',
#    ' untimely',
#    ' slavery',
#    ' continued practice',
#    ' prima facie',
#    ' eligibility',
#    ' suppression',
#    ' activist',
#    ' merits'],
#   'op_length': 4031},
#  {'name': 'Guartazaca v. Garland, 2022 U.S. App. LEXIS 4774',
#   'decision': 'denied',
#   'country': <re.Match object; span=(229, 5554), match='citizen of Ecuador, seeks review of a November 7,>,
#   'terms': ['torture',
#    ' removal',
#    ' motive',
#    ' gangs',
#    ' targeted',
#    ' petition for review',
#    ' withholding',
#    ' adolescent',
#    ' social group',
#    ' no error',
#    ' circumstances',
#    ' patriarchal',
#    ' persecution',
#    ' speculative',
#    ' conditions',
#    ' membership',
#    ' extorted',
#    ' inhuman',
#    ' severe',
#    ' chain',
#    ' cruel',
#    ' nexus',
#    ' male'],
#   'op_length': 5656},
#  {'name': 'Haipeng Wu v. Wilkinson, 846 Fed. Appx. 56',
#   'decision': 'denied',
#   'country': <re.Match object; span=(222, 4573), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['corroboration',
#    ' burden of proof',
#    ' petition for review',
#    ' Immigration',
#    ' church',
#    ' alien',
#    ' immigration authorities',
#    ' corroborative evidence',
#    ' reasonably available',
#    ' trier of fact',
#    ' documentation',
#    ' explanations',
#    ' well-founded',
#    ' persecution',
#    ' unavailable',
#    ' practicing',
#    ' religious',
#    ' Torture',
#    ' attend'],
#   'op_length': 4675},
#  {'name': 'Hossain v. Barr, 794 Fed. Appx. 123',
#   'decision': 'granted',
#   'country': <re.Match object; span=(317, 3853), match='citizen of Bangladesh, seeks review of a BIA deci>,
#   'terms': ['petition for review',
#    ' proceedings',
#    ' removal',
#    ' ineffective assistance claim',
#    ' abuse of discretion',
#    ' ineffective',
#    ' competence',
#    ' careless',
#    ' abused',
#    ' reopen'],
#   'op_length': 3937},
#  {'name': 'Jian Long Dong v. Garland, 852 Fed. Appx. 45',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 2282), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['petition for review',
#    ' motion to reopen',
#    ' conditions',
#    ' removal proceedings',
#    ' family planning',
#    ' untimely',
#    ' reopen'],
#   'op_length': 2317},
#  {'name': 'Jin v. United States Citizenship & Immigration Servs., 2022 U.S. Dist. LEXIS 181171',
#   'decision': None,
#   'country': None,
#   'terms': ['resides',
#    ' proper venue',
#    ' judicial district',
#    ' mandamus relief',
#    ' give rise',
#    ' interest of justice',
#    ' substantial part',
#    ' real property',
#    ' transfers',
#    ' venue'],
#   'op_length': 2624},
#  {'name': 'Kabir v. Barr, 801 Fed. Appx. 829',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 3445), match='citizen of Bangladesh, seeks review of a July 16,>,
#   'terms': ['conditions',
#    ' reopening',
#    ' motion to reopen',
#    ' untimely',
#    ' petition for review',
#    ' articles',
#    ' denial of a motion',
#    ' political violence',
#    ' material change',
#    ' proceedings',
#    ' crackdown',
#    ' religious',
#    ' merits'],
#   'op_length': 3554},
#  {'name': 'Kapoor v. Demarco, 2022 U.S. Dist. LEXIS 169792',
#   'decision': None,
#   'country': <re.Match object; span=(514, 7698), match='citizen of India. She entered the United States i>,
#   'terms': ['extradition', ' torture', ' surrender', ' habeas corpus'],
#   'op_length': 7725},
#  {'name': 'Lin v. Garland, 2021 U.S. Dist. LEXIS 144362',
#   'decision': None,
#   'country': None,
#   'terms': ['prevailing party', " attorney's fees", ' moot'],
#   'op_length': 1586},
#  {'name': 'Manjit Singh v. Garland, 2021 U.S. App. LEXIS 37359',
#   'decision': 'denied',
#   'country': <re.Match object; span=(236, 4316), match='citizen of India, seeks review of a December 17, >,
#   'terms': ['credibility',
#    ' inconsistencies',
#    ' corroboration',
#    ' demeanor',
#    ' defer',
#    ' totality of the circumstances',
#    ' credibility determinations',
#    ' petition for review',
#    " applicant's claim",
#    ' cross-examination',
#    ' rehabilitate',
#    ' declining',
#    ' reliable',
#    ' letters'],
#   'op_length': 4418},
#  {'name': 'Mendoza-Ventura v. Garland, 2022 U.S. App. LEXIS 9617',
#   'decision': 'granted',
#   'country': <re.Match object; span=(236, 3916), match='citizen of Honduras, seeks review of a November 2>,
#   'terms': ['persecution',
#    ' political opinion',
#    ' petition for review',
#    ' anticorruption',
#    ' corruption',
#    ' removal',
#    ' abuse of power',
#    ' withholding'],
#   'op_length': 4060},
#  {'name': 'Moumouni Hamida v. Garland, 2021 U.S. App. LEXIS 33527',
#   'decision': 'denied',
#   'country': <re.Match object; span=(227, 3027), match='citizen of Niger, seeks review of a December 31, >,
#   'terms': ['conditions',
#    ' reopen',
#    ' petition for review',
#    ' motion to reopen',
#    ' material change',
#    ' removal proceedings',
#    ' medical condition',
#    ' time limit'],
#   'op_length': 3129},
#  {'name': 'Ojeda v. Garland, 2022 U.S. App. LEXIS 11919',
#   'decision': 'denied',
#   'country': <re.Match object; span=(240, 6915), match='citizen of Mexico, seeks review of an August 7, 2>,
#   'terms': ['egregious', ' deadline', ' identification', ' suppress'],
#   'op_length': 7017},
#  {'name': 'Omorodion v. Garland, 2022 U.S. App. LEXIS 32796',
#   'decision': 'granted',
#   'country': <re.Match object; span=(312, 7940), match='citizen of Nigeria, seeks review of a July 30, 20>,
#   'terms': ['torture', ' VACATED', ' removal'],
#   'op_length': 8084},
#  {'name': 'Paltan-Daquilema v. Garland, 855 Fed. Appx. 65',
#   'decision': 'denied',
#   'country': <re.Match object; span=(241, 3170), match='citizen of Ecuador, seeks review of a February 28>,
#   'terms': ['credibility finding',
#    ' petition for review',
#    ' corroborate',
#    ' credibility',
#    ' persecution',
#    ' abandoned',
#    ' deadline',
#    ' argues'],
#   'op_length': 3272},
#  {'name': 'Purba v. Barr, 824 Fed. Appx. 69',
#   'decision': 'denied',
#   'country': <re.Match object; span=(234, 4791), match='citizen of Indonesia, seeks review of a February >,
#   'terms': ['conditions',
#    ' reopening',
#    ' motion to reopen',
#    ' petition for review',
#    ' sua sponte',
#    ' religious',
#    ' removal',
#    ' final administrative decision',
#    ' removal proceedings',
#    ' supporting evidence',
#    ' material change',
#    ' Immigration',
#    ' Provisional',
#    ' proceedings',
#    ' instances',
#    ' religions',
#    ' violence',
#    ' USCIS'],
#   'op_length': 4900},
#  {'name': 'Rafiq v. Barr, 821 Fed. Appx. 59',
#   'decision': 'denied',
#   'country': <re.Match object; span=(223, 3454), match='citizen of Pakistan, seeks review of a January 11>,
#   'terms': ['conditions',
#    ' motion to reopen',
#    ' prima facie',
#    ' eligibility',
#    ' attackers',
#    ' petition for review',
#    ' killed',
#    ' material change',
#    ' proceedings',
#    ' extremists',
#    ' removal',
#    ' reopen'],
#   'op_length': 3556},
#  {'name': 'Rodriguez v. Garland, 2021 U.S. Dist. LEXIS 226249',
#   'decision': None,
#   'country': <re.Match object; span=(829, 31674), match='citizen of Honduras. Docket Item 4-1 at ¶ 5. He s>,
#   'terms': ['detention',
#    ' noncitizen',
#    ' removal',
#    ' immigration',
#    ' prolonged',
#    ' detained',
#    ' continued detention',
#    ' custody',
#    ' due process',
#    ' violates',
#    ' conditions',
#    ' clear and convincing evidence',
#    ' removal proceedings',
#    ' deportation',
#    ' flight',
#    ' procedural due process',
#    ' individualized',
#    ' detainees',
#    ' Appeals',
#    ' factors',
#    ' argues',
#    ' courts',
#    ' governmental interest',
#    ' decisionmaker',
#    ' imprisonment',
#    ' confinement',
#    ' weigh'],
#   'op_length': 31753},
#  {'name': 'Rojas v. Garland, 2022 U.S. App. LEXIS 30904',
#   'decision': 'denied',
#   'country': <re.Match object; span=(240, 2911), match='citizen of Ecuador, seeks review of an April 18, >,
#   'terms': ['reconsideration motion',
#    ' adverse-credibility',
#    ' inconsistencies',
#    ' petition for review',
#    ' error of law',
#    ' excused',
#    ' removal'],
#   'op_length': 3013},
#  {'name': 'R.R.M.C. v. Decker, 2022 U.S. Dist. LEXIS 179302',
#   'decision': 'granted',
#   'country': <re.Match object; span=(58, 19784), match='citizen and native of Honduras, is detained by U.>,
#   'terms': ['flight risk',
#    ' detention',
#    ' immigration',
#    ' clear and convincing evidence',
#    ' reasonable condition',
#    ' mitigated',
#    ' burden of proof',
#    ' proceedings',
#    ' convinced',
#    ' danger to the community',
#    ' question of law',
#    ' legal standard',
#    ' supervision',
#    ' compliance',
#    ' monitoring',
#    ' returning',
#    ' complies',
#    ' monetary',
#    ' factors',
#    ' removal'],
#   'op_length': 19861},
#  {'name': 'Rudersdal v. Harris, 2020 U.S. Dist. LEXIS 255673',
#   'decision': 'granted',
#   'country': <re.Match object; span=(114692, 172289), match='citizen of Bulgaria. (See Compl. ¶¶ 11-15.) Plain>,
#   'terms': ["Plaintiffs'",
#    ' courts',
#    ' personal jurisdiction',
#    ' discovery',
#    ' general jurisdiction',
#    ' contacts',
#    ' long-arm',
#    ' forum non conveniens',
#    ' entities',
#    " Defendants'",
#    ' parties',
#    ' funds',
#    ' motion to dismiss',
#    ' allegations',
#    ' deference',
#    ' corruption',
#    ' cases',
#    ' bankruptcy proceedings',
#    ' choice of forum',
#    ' assessing',
#    ' requests',
#    ' situs',
#    ' alternative forum',
#    ' Declaration',
#    ' prima facie case',
#    ' convenient',
#    ' sovereign',
#    ' supplemental agreement',
#    ' district court',
#    ' bank account'],
#   'op_length': 172298},
#  {'name': 'Saleh v. United States Citizenship & Immigration Servs., 2022 U.S. Dist. LEXIS 78310',
#   'decision': 'granted',
#   'country': <re.Match object; span=(22068, 59910), match='citizen within seven years as required for immigr>,
#   'terms': ['Naturalization',
#    ' Military',
#    ' arrest',
#    ' interviewed',
#    ' Refugee',
#    ' summary judgment',
#    ' statement of facts',
#    ' terrorist organization',
#    ' alien',
#    ' immigration',
#    ' Forces',
#    ' terrorist activity',
#    ' incarceration',
#    ' Responding',
#    ' terrorists',
#    ' Coalition',
#    ' killed',
#    ' lawfully admitted',
#    ' citizenship',
#    ' asserting',
#    ' questions',
#    ' friends',
#    ' genuine',
#    ' food',
#    ' summary judgment motion',
#    ' good moral character',
#    ' permanent resident',
#    ' inadmissibility',
#    ' imprisoned',
#    ' disputed'],
#   'op_length': 59919},
#  {'name': 'Singh v. Barr, 799 Fed. Appx. 23',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 4919), match='citizen of India, seeks review of a December 13, >,
#   'terms': ['alien',
#    ' reissue',
#    ' mail',
#    ' motion to reopen',
#    ' petition for review',
#    ' proceedings',
#    ' exhaust',
#    ' removal',
#    ' deny a motion',
#    ' law firm',
#    ' non-receipt',
#    ' asserting',
#    ' declining',
#    ' pursuing',
#    ' Appeals',
#    ' reasons',
#    ' argues',
#    ' reopen',
#    ' fault'],
#   'op_length': 5021},
#  {'name': 'Singh v. Garland, 853 Fed. Appx. 761',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 4526), match='citizen of India, seeks review of a March 8, 2019>,
#   'terms': ['reopen',
#    ' motion to reopen',
#    ' persecution',
#    ' new evidence',
#    ' petition for review',
#    ' deny a motion',
#    ' family member',
#    ' harassment',
#    ' attacked',
#    ' credibility determinations',
#    ' political affiliation',
#    ' prima facie case',
#    ' rehabilitate',
#    ' well-founded',
#    ' Immigration',
#    ' credibility',
#    ' quotation',
#    ' rising',
#    ' marks'],
#   'op_length': 4628},
#  {'name': 'Singh v. Garland, 2022 U.S. App. LEXIS 16011',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 4283), match='citizen of India, seeks review of a February 26, >,
#   'terms': ['petition for review',
#    ' reconsideration',
#    ' attacked',
#    ' reasons',
#    ' credibility determinations',
#    ' reconsideration motion',
#    ' deny reconsideration',
#    ' documentary evidence',
#    ' medical report',
#    ' Immigration',
#    ' reliability',
#    ' reconsider',
#    ' quotation',
#    ' abused',
#    ' marks',
#    ' beat'],
#   'op_length': 4385},
#  {'name': 'Singh v. Garland, 2022 U.S. App. LEXIS 19092',
#   'decision': 'denied',
#   'country': <re.Match object; span=(227, 2740), match='citizen of India, seeks review of a March 2, 2020>,
#   'terms': ['motion to reopen',
#    ' conditions',
#    ' petition for review',
#    ' reopening',
#    ' credibility',
#    ' referendum',
#    ' supporters'],
#   'op_length': 2842},
#  {'name': 'Sukhwinder Singh v. Garland, 2022 U.S. App. LEXIS 6592',
#   'decision': 'denied',
#   'country': <re.Match object; span=(217, 3344), match='citizen of India, seeks review of a February 5, 2>,
#   'terms': ['relocate',
#    ' persecution',
#    ' well-founded',
#    ' safely',
#    ' petition for review',
#    ' withholding',
#    ' presumed',
#    ' rebut'],
#   'op_length': 3379},
#  {'name': 'Thomas v. Garland, 2022 U.S. App. LEXIS 9213',
#   'decision': 'denied',
#   'country': <re.Match object; span=(223, 2379), match='citizen of Albania, seeks review of an October 18>,
#   'terms': ['conditions',
#    ' petition for review',
#    ' removal',
#    ' reopen',
#    ' change condition',
#    ' motion to reopen'],
#   'op_length': 2481},
#  {'name': 'Vasquez v. Garland, 2022 U.S. App. LEXIS 30382',
#   'decision': 'denied',
#   'country': <re.Match object; span=(234, 4515), match='citizen of Guatemala, seeks review of an August 3>,
#   'terms': ['persecution',
#    ' petition for review',
#    ' probability',
#    ' withholding',
#    ' removal',
#    ' threats',
#    ' killed',
#    ' family member',
#    ' sell drugs',
#    ' credibility',
#    ' caller',
#    ' cartel',
#    ' courts',
#    ' harmed'],
#   'op_length': 4617},
#  {'name': 'Xuexia Feng v. Garland, 846 Fed. Appx. 75',
#   'decision': 'denied',
#   'country': <re.Match object; span=(223, 3960), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['motion to reopen',
#    ' new evidence',
#    ' persecution',
#    ' torture',
#    ' petition for review',
#    ' per curiam',
#    ' quotation',
#    ' targets',
#    ' marks',
#    ' prima facie case',
#    ' credibility',
#    ' withholding',
#    ' violence',
#    ' removal',
#    ' reopen'],
#   'op_length': 4062},
#  {'name': 'Xu v. Garland, 2022 U.S. App. LEXIS 1008',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 4600), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['persecution',
#    ' church',
#    ' authorities',
#    ' attend',
#    ' petition for review',
#    ' well-founded',
#    ' practicing',
#    ' letters',
#    ' gospel',
#    ' spread',
#    ' underground',
#    ' strangers',
#    ' arrested',
#    ' solid'],
#   'op_length': 4702},
#  {'name': 'Yan Rong Liu v. Barr, 825 Fed. Appx. 26',
#   'decision': 'denied',
#   'country': <re.Match object; span=(224, 3883), match='citizen of the People\'s Republic of China, seeks>,
#   'terms': ['conditions',
#    ' motion to reopen',
#    ' petition for review',
#    ' administrative notice',
#    ' change condition',
#    ' material change',
#    ' per curiam',
#    ' demonstrates',
#    ' untimely',
#    ' motions'],
#   'op_length': 4019},
#  {'name': 'Yun Qing Huang v. Garland, 852 Fed. Appx. 609',
#   'decision': 'denied',
#   'country': <re.Match object; span=(226, 2511), match='citizen of China, seeks review of a November 16, >,
#   'terms': ['credibility determinations',
#    ' petition for review',
#    ' exhaust',
#    ' meaningfully',
#    ' credibility',
#    ' reasons',
#    ' waived'],
#   'op_length': 2613},
#  {'name': 'Marin v. Garland, 2022 U.S. App. LEXIS 32152',
#   'decision': 'denied',
#   'country': <re.Match object; span=(227, 4034), match='citizen of Colombia, seeks review of an August 27>,
#   'terms': ['torture',
#    ' petition for review',
#    ' murder',
#    ' substantial evidence',
#    ' relevant evidence',
#    ' targeted',
#    ' violence'],
#   'op_length': 4136}]

# %%
len(asylum_cases_organized)
# Out:
# 667

# %% [markdown]
# #### Now I convert all the country regex matches into strings of the countries. Also check all the places regex didn't work. Manually. And drop ones that don't apply to my query

# %%
asylum_df = pd.DataFrame(asylum_cases_organized)

# %%
pd.options.display.max_colwidth = None

# %%
asylum_df
# Out:
#                                               name decision  \
# 0            Zepeda-Lopez v. Garland, 38 F.4th 315  granted
# 1              Quituizaca v. Garland, 52 F.4th 103   denied
# 2                   Liang v. Garland, 10 F.4th 106   denied
# 3         Doleck Nepali v. Barr, 828 Fed. Appx. 14   denied
# 4        Fangfang Xu v. Cissna, 434 F. Supp. 3d 43  granted
# ..                                             ...      ...
# 662      Xuexia Feng v. Garland, 846 Fed. Appx. 75   denied
# 663       Xu v. Garland, 2022 U.S. App. LEXIS 1008   denied
# 664        Yan Rong Liu v. Barr, 825 Fed. Appx. 26   denied
# 665  Yun Qing Huang v. Garland, 852 Fed. Appx. 609   denied
# 666   Marin v. Garland, 2022 U.S. App. LEXIS 32152   denied
#
#                                                                                              country  \
# 0    <re.Match object; span=(1027, 27063), match='citizens of both Honduras and Nicaragua. They app>
# 1    <re.Match object; span=(1345, 40382), match='citizen of Ecuador, entered the United States in >
# 2     <re.Match object; span=(819, 28175), match='citizen of the People\'s Republic of China, illeg>
# 3      <re.Match object; span=(238, 9751), match='citizen of Nepal, seeks review of a November 28, >
# 4      <re.Match object; span=(63, 43720), match='citizen of the People\'s Republic of China, appli>
# ..                                                                                               ...
# 662    <re.Match object; span=(223, 3960), match='citizen of the People\'s Republic of China, seeks>
# 663    <re.Match object; span=(224, 4600), match='citizen of the People\'s Republic of China, seeks>
# 664    <re.Match object; span=(224, 3883), match='citizen of the People\'s Republic of China, seeks>
# 665    <re.Match object; span=(226, 2511), match='citizen of China, seeks review of a November 16, >
# 666    <re.Match object; span=(227, 4034), match='citizen of Colombia, seeks review of an August 27>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         terms  \
# 0                                                                                                                                                                                            [refugee,  <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>,  nationality,  dual,  persecution,  citizenship,  singular,  removal,  legislative history,  resettlement,  well-founded,  withholding,  unwilling,  eligible,  deference,  qualify,  refugee status,  statutory text,  Immigration,  proceedings,  policies,  gang]
# 1                                                                             [withholding,  <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>,  removal,  motive,  persecution,  gang,  alien,  ethnicity,  but-for,  ambiguity,  causation,  withholding-of-removal,  eligibility,  Immigration,  concurrence,  credibility,  unambiguous,  deference,  burden of proof,  social group,  indigenous,  persuasive,  attacks,  waived,  petition for review,  plain meaning,  plain text,  nationality,  persecutor,  suggests]
# 2                                                                                                                                                                                                             [persecution,  blacklist,  <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>,  removal,  omission,  credibility,  credibility determinations,  withholding,  quotation,  marks,  cross-examination,  inconsistencies,  church,  totality of the circumstances,  well-founded,  corroborate,  disclose,  eligible]
# 3                                                                                                                                                                                                                                                                                                                                                                                 [persecution,  <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>,  terrorist,  removal,  credibility determinations,  withholding,  credible]
# 4    [<span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>,  adjudicate,  delays,  motion to dismiss,  mandamus,  USCIS,  lack subject matter jurisdiction,  unreasonable delay,  plaintiff's claim,  allegations,  fail to state a claim,  pleadings,  quotation,  due process,  time frame,  reasons,  courts,  alien,  marks,  subject matter jurisdiction,  immigration,  factors,  rights,  private right of action,  judicial review,  rule of reason,  timetable,  due process claim,  plaintiff's right,  reasonable time]
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 662                                                                                                                                                                                                                                                                                                                                   [motion to reopen,  new evidence,  persecution,  torture,  petition for review,  per curiam,  quotation,  targets,  marks,  prima facie case,  credibility,  withholding,  violence,  removal,  reopen]
# 663                                                                                                                                                                                                                                                                                                                                                                  [persecution,  church,  authorities,  attend,  petition for review,  well-founded,  practicing,  letters,  gospel,  spread,  underground,  strangers,  arrested,  solid]
# 664                                                                                                                                                                                                                                                                                                                                                                       [conditions,  motion to reopen,  petition for review,  administrative notice,  change condition,  material change,  per curiam,  demonstrates,  untimely,  motions]
# 665                                                                                                                                                                                                                                                                                                                                                                                                                              [credibility determinations,  petition for review,  exhaust,  meaningfully,  credibility,  reasons,  waived]
# 666                                                                                                                                                                                                                                                                                                                                                                                                                                 [torture,  petition for review,  murder,  substantial evidence,  relevant evidence,  targeted,  violence]
#
#      op_length
# 0        27169
# 1        40390
# 2        28201
# 3         9853
# 4        43803
# ..         ...
# 662       4062
# 663       4702
# 664       4019
# 665       2613
# 666       4136
#
# [667 rows x 5 columns]

# %%
def regex_to_country(rematch):
    entire_str = rematch.string[rematch.start():]
    country = ''
    for word in entire_str.split(" "):
        print(word)
        if word.lower() == "citizen" or word.lower() == "citizens" or word.lower() == "of" or word.lower() == "the" or word.lower() == "and" or word.lower() == "both":
            continue
        elif word[:2].istitle():
            country += word+" "
        else:
            break
    country.strip().strip(",")
    return country

# %%
asylum_df["country"] = asylum_df["country"].apply(lambda x: regex_to_country(x) if(x != None) else x==None)
# Out:
# citizens
# of
# both
# Honduras
# and
# Nicaragua.
# They
# applied
# citizen
# of
# Ecuador,
# entered
# citizen
# of
# the
# People's
# Republic
# of
# China,
# illegally
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# applied
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# El
# Salvador,
# testified
# citizen
# of
# Guatemala,
# seeks
# citizens
# of
# Honduras.
# They
# left
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Nigeria,
# entered
# citizen
# of
# Cameroon,
#  [*111]
# citizens
# of
# Bangladesh,
# and
# Sadid
# Hassan
# and
# Samara
# Hassan,
# seek
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Guatemala
# and
# a
# citizens
# of
# Guatemala,
# seek
# citizen
# of
# Honduras,
# testified
# citizens
# of
# Nepal,
# seek
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# India
# who
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# Democratic
# Republic
# of
# the
# Congo,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Jamaica
# who,
# citizen
# of
# India,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# El
# Salvador.
# As
# evidence
# citizen
# of
# India,
# was
# citizen
# of
# Sri
# Lanka,
# seeks
# citizen
# of
# Haiti,
# seeks
# citizen
# of
# El
# Salvador.
# Martinez
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# El
# Salvador
# who
# citizens
# from
# citizen
# of
# China,
# alleges
# citizens
# to
# citizens
# of
# the
# People's
# Republic
# of
# China.
# After
# they
# citizens
# present
# citizen
# of
# Honduras.
# (Dkt.
# 4-1
# citizens
# of
# the
# People's
# Republic
# of
# China.
# Compl.
# ¶
# citizen
# of
# Honduras.
# (Dkt.
# 8-1
# citizen
# of
# Guatemala
# born
# citizen
# of
# India.
# (Dkt.
# 5-1
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Peru,
# seeks
# citizens
# of
# Uzbekistan,
# seek
# citizen
# of
# Senegal,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Sri
# Lanka,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India
# seeking
# citizen
# of
# India,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
#  [*681]
# citizen
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Pakistan,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Guinea,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
#  [*24]
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# the
# Democratic
# Republic
# of
# Congo
# ("DRC"),
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# Russia,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Burundi,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# India,
# seeks
# citizens
# claiming
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# the
# People's
# Republic
# of
# China,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# the
# People's
# Republic
# of
# China,
# seek
# citizen
# of
# Ethiopia,
# seeks
# citizen
# of
# Haiti,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# China,
# seeks
# citizens
# of
# Brazil,
# seek
# citizen
# of
# El
# Salvador,
# seeks
# citizens
# of
# the
# Czech
# Republic,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Ghana,
# seeks
# citizens
# of
# Honduras,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Algeria,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Albania,
# seeks
# citizens
# of
# Albania,
# seek
# citizens
# of
# India,
# seek
# citizen
# of
# Pakistan,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizens
# of
# Guatemala,
# seek
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Russia,
# and
# her
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# India,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Somalia,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Colombia,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# the
# People's
# Republic
# of
# China,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Russia,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# Central
# African
# Republic,
# seeks
# citizen
# of
# Belize,
# seeks
# citizens
# of
# Ecuador,
# seek
# citizen
# of
# Haiti.
# (Dkt.
# 6-1
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# Dominican
# Republic,
# seeks
# citizens
# of
# Guatemala,
# allegedly
# citizens
# into
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# Burundi,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# was
# citizen
# of
# Montenegro,
# seeks
# citizen
# of
# Nigeria,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# Ghana,
# seeks
# citizen
# of
# Sri
# Lanka.
# See
# Dkt.
# No.
# 23
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizens
# of
# Honduras,
# seek
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Nicaragua,
# seeks
# citizens
# of
# Ecuador,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# may
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# the
# People's
# Republic
# of
# China,
# seek
# citizen
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Pakistan,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# Pakistan,
# seek
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# Nepal,
# seek
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizens
# of
# Guatemala,
# seek
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# granted
# citizen
# of
# Pakistan,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# petitions
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# petitions
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizens
# of
# Albania,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Kazakhstan,
# seeks
# citizen
# of
# Pakistan,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# China
# seeking
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Mexico.
# Declaration
# of
# Cesar
# Espinoza-Zeferino
# ("Espinoza
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Guinea,
# seeks
# citizen
# of
# [TEXT
# REDACTED
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# Honduras.
# On
# December
# 12,
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# St.
# Kitts-Nevis
# who
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Trinidad
# and
# Tobago
# who
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# Democratic
# Republic
# of
# the
# Congo
# ("Congo"),
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nicaragua,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# Guatemala,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Jamaica,
# arrived
# citizen
# who
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Yemen,
# to
# citizen
# of
# Haiti,
# seeks
# citizens
# of
# Guatemala,
# seek
# citizen
# unlawfully
# citizen
# of
# El
# Salvador,
# entered
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Spain
# and
# Portugal;
# Guillaume
# is
# citizen
# of
# The
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Jamaica.
# (Dkt.
# 12-1
# citizen
# of
# Ghana,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Côte
# d'Ivoire,
# citizen
# of
# the
# Republic
# of
# Guinea.
# (Dkt.
# 4
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Jamaica,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# and
# native
# citizen
# of
# Côte
# d'Ivoire,
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Russia,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# the
# Dominican
# Republic
# who
# citizens
# to
# citizen
# of
# the
# Dominican
# Republic,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# El
# Salvador.
# (Dkt.
# 8-1
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# India,
# seeks
# citizens
# and
# lawful
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# Nigeria,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizens
# of
# Honduras,
# seek
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Haiti,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Haiti,
# seeks
# citizen [**2]
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Sri
# Lanka,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizens
# of
# Honduras,
# seek
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Mongolia,
# seeks
# citizen
# of
# Mexico,
# asks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Albania,
# seeks
# citizen
# of
# Jamaica.
# On
# July
# 28,
# citizen
# of
# Jamaica.
# On
# July
# 28,
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# China,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Sri
# Lanka,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Brazil,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# has
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Guatemala.
# (Dkt.
# 5
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# Ethiopia,
# seeks
# citizen
# of
# Indonesia,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Haiti,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizens
# of
# El
# Salvador,
# seek
# citizen
# of
# Jamaica,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizens
# of
# Guatemala,
# seek
# citizen
# of
# Honduras,
# seeks
# citizens
# of
# Guatemala,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# the
# Dominican
# Republic
# who
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Algeria,
# seeks
# citizen
# who
# citizen
# of
# Kenya,
# seeks
# citizen
# of
# Haiti,
# seeks
# citizens
# of
# Mexico,
# seek
# citizen
# of
# Liberia,
# brings
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Peru,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizens
# of
# the
# People's
# Republic
# of
# China,
# seek
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Trinidad
# and
# Tobago,
# seeks
# citizen
# of
# Chile.
# (ECF
# No.
# 21-2
# citizen
# of
# Peru,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# Democratic
# Republic
# of
# Congo,
# seeks
# citizen
# of
# Pakistan,
# commenced
# citizen
# of
# the
# United
# States.
# (Id.).
# On
# August
# 7,
# citizen
# of
# El
# Salvador,
# last
# citizen
# of
# El
# Salvador,
# seeks
# citizen [*3]
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# Dominican
# Republic,
# seeks
# citizen
# of
# Guinea,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# children
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Jamaica
# who
# citizen
# of
# India,
# seeks
# citizen
# of
# Pakistan,
# commenced
# citizen
# of
# Somalia,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Honduras.
# (See
# Dkt.
# 1
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# Indonesia,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Mauritania,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# Dominican
# Republic
# (Dkt.
# 1
# citizen
# of
# Jamaica,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Guatemala,
# petitions
# citizen
# of
# Jamaica.
# Dkt.
# 1,
# citizen
# of
# India,
# seeks
# citizen
# of
# Belize,
# seeks
# citizen
# of
# Jamaica.
# (Dkt.
# 11-1
# citizen
# of
# Honduras,
# seeks
# citizens
# of
# the
# People's
# Republic
# of
# China,
# seek
# citizen
# of
# Trinidad
# and
# Tobago,
# seeks
# citizen
# of
# Nepal,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# the
# Republic
# of
# Guinea,
# was
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Liberia,
# was
# citizens
# of
# Kosovo,
# seek
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# convicted
# citizens
# of
# Guatemala,
# seek
# citizen
# of
# Senegal,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Pakistan,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# Jamaica,
# seeks
# citizen
# of
# Nigeria,
# was
# citizen
# of
# Peru,
# seeks
# citizen
# of
# El
# Salvador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Mauritania,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# Bangladesh,
# seeks
# citizen
# of
# India.
# She
# entered
# citizen
# of
# India,
# seeks
# citizen
# of
# Honduras,
# seeks
# citizen
# of
# Niger,
# seeks
# citizen
# of
# Mexico,
# seeks
# citizen
# of
# Nigeria,
# seeks
# citizen
# of
# Ecuador,
# seeks
# citizen
# of
# Indonesia,
# seeks
# citizen
# of
# Pakistan,
# seeks
# citizen
# of
# Honduras.
# Docket
# Item
# 4-1
# citizen
# of
# Ecuador,
# seeks
# citizen
# and
# native
# citizen
# of
# Bulgaria.
# (See
# Compl.
# ¶¶
# citizen
# within
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# India,
# seeks
# citizen
# of
# Albania,
# seeks
# citizen
# of
# Guatemala,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# the
# People's
# Republic
# of
# China,
# seeks
# citizen
# of
# China,
# seeks
# citizen
# of
# Colombia,
# seeks

# %%
asylum_df[asylum_df["country"].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, decision, country, terms, op_length]
# Index: []

# %%
asylum_df.at[277, 'country'] = "Guatemala"
asylum_df.at[299, 'country'] = "Cameroon"
asylum_df.at[337, 'country'] = "China"
asylum_df.at[347, 'country'] = "confidential"
asylum_df.at[224, 'country'] = "Honduras"
asylum_df.at[410, 'country'] = "Bangladesh"
asylum_df.at[453, 'country'] = "Dominican Republic"
asylum_df.at[528, 'country'] = "Somalia"
asylum_df.at[569, 'country'] = "Mexico"
asylum_df.at[615, 'country'] = "Saint Lucia"
asylum_df.at[630, 'country'] = "not mentioned"
asylum_df.at[638, 'country'] = "not mentioned"
asylum_df.at[652, 'country'] = "Honduras"
asylum_df.at[654, 'country'] = "Iraq"

# %%
asylum_df.at[26, 'decision'] = "partially granted"
asylum_df.at[44, 'decision'] = "partially granted"
asylum_df.at[46, 'decision'] = "partially granted"
asylum_df.at[49, 'decision'] = "partially granted"
asylum_df.at[109, 'decision'] = "granted"
asylum_df.at[219, 'decision'] = "denied"
asylum_df.at[224, 'decision'] = "partially granted"
asylum_df.at[277, 'decision'] = "partially granted"
asylum_df.at[300, 'decision'] = "denied"
asylum_df.at[349, 'decision'] = "denied"
asylum_df.at[351, 'decision'] = "denied"
asylum_df.at[375, 'decision'] = "granted"
asylum_df.at[380, 'decision'] = "denied"
asylum_df.at[382, 'decision'] = "partially granted"
asylum_df.at[392, 'decision'] = "partially granted"
asylum_df.at[401, 'decision'] = "partially granted"
asylum_df.at[418, 'decision'] = "partially granted"
asylum_df.at[422, 'decision'] = "denied"
asylum_df.at[453, 'decision'] = "partially granted"
asylum_df.at[473, 'decision'] = "denied"
asylum_df.at[500, 'decision'] = "partially granted"
asylum_df.at[521, 'decision'] = "denied"
asylum_df.at[545, 'decision'] = "granted"
asylum_df.at[547, 'decision'] = "denied"
asylum_df.at[556, 'decision'] = "partially granted"
asylum_df.at[560, 'decision'] = "partially granted"
asylum_df.at[567, 'decision'] = "denied"
asylum_df.at[570, 'decision'] = "partially granted"
asylum_df.at[588, 'decision'] = "partially granted"
asylum_df.at[595, 'decision'] = "partially granted"
asylum_df.at[638, 'decision'] = "partially granted"
asylum_df.at[640, 'decision'] = "denied"
asylum_df.at[650, 'decision'] = "partially granted"

# %%
droplist = [30, 32, 33, 41, 42, 43, 45, 48, 128, 206, 233, 269, 331, 335, 376, 381, 418, 419, 426, 461, 472, 487, 532, 536, 545, 555, 558, 572, 575, 632, 638, 641, 39, 43, 272, 307]
len(droplist)
# Out:
# 36

# %%
asylum_df = asylum_df.drop(droplist) #cannot run this again scared of error message

# %% [markdown]
# ### Now clean up the country column

# %%
# to get country by name, without the letters surrounding it.
asylum_df.country = asylum_df.country.str.replace(r"[,.;].*", "")
asylum_df.country = asylum_df.country.str.strip()
# Out:
# /var/folders/zr/2lz5ysfx1x33mrrqv606s8sr0000gn/T/ipykernel_22911/3251335375.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   asylum_df.country = asylum_df.country.str.replace(r"[,.;].*", "")

# %%
asylum_df[asylum_df.country == ""]
# Out:
#                                                name           decision  \
# 109  Ramirez v. Decker, 2020 U.S. Dist. LEXIS 39535            granted
# 560    Cano v. Decker, 2022 U.S. Dist. LEXIS 223992  partially granted
# 567       Gao v. Wolf, 2020 U.S. Dist. LEXIS 213957             denied
#
#     country  \
# 109
# 560
# 567
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  terms  \
# 109  [custody,  arrested,  aliens,  parole,  <span name="SH_2355451274" class="SS_prior SS_SH">asylum</span>,  least restrictive,  immigration,  transferred,  removal proceedings,  arriving,  sponsor,  immigration judge,  border,  flight risk,  detention,  credible,  detained,  placement,  turning,  danger to the community,  supervision,  notice,  physical custody,  18 year old,  respectfully,  conditions,  recommend,  jail,  persecution,  Directive]
# 560                                                                                                                                                                                                                                       [burden of proof,  disability,  danger to the community,  Immigration,  detention,  custody,  clear and convincing evidence,  due process,  flight risk,  private interest,  habeas petition,  detained,  disorder,  argues]
# 567                                                                                                                                                                                    [removal order,  Immigration,  alien,  court of appeals,  eligibility,  paroled,  permanent resident,  discretionary,  lack jurisdiction,  inspected,  removal,  application for adjustment,  motion to dismiss,  district court,  subject-matter,  appeals,  factors,  courts]
#
#      op_length
# 109      37988
# 560      12960
# 567      19353

# %%
asylum_df.at[109, 'country'] = "Guatemala"
asylum_df.at[560, 'country'] = "Guatemala"
asylum_df.at[567, 'country'] = "China"
asylum_df.at[351, 'country'] = "St. Kitts-Nevis"
asylum_df.at[556, 'country'] = "not mentioned"
asylum_df.country = asylum_df.country.str.replace("People's Republic of China", "China").str.replace("People's Republic China", "China")

# %%
asylum_df.to_csv("asylum_data.csv", index = False)
